# %% [markdown]
# <a href="https://colab.research.google.com/github/zackyalgiffari/CathyGaisCountDataset/blob/main/Text_Mining_Gais_Cathculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #GaisCathculator
#
# Project Description:
#
# This project aims to analyze the frequency of the word "gais" in the posts made by the X account N_CathyJKT48. The dataset consists of posts from Cathy's X account, and the goal is to count how many times the word "gais" appears in her posts. Additionally, the project calculates the total number of posts made by Cathy on X.
#
# Author: @zacathy48

# %%
#Import library
import pandas as pd

# %%
#File path link

file_path1 = 'https://raw.githubusercontent.com/zackyalgiffari/CathyGaisCountDataset/main/CathyGais%208%20Maret%202024.csv'
file_path2 = 'https://raw.githubusercontent.com/zackyalgiffari/CathyGaisCountDataset/main/CathyGaiss%208%20Maret%202024.csv'
file_path3 = 'https://raw.githubusercontent.com/zackyalgiffari/CathyGaisCountDataset/main/CathyGaisss%208%20Maret%202024.csv'

# read first csv file
df1 = pd.read_csv(file_path1, delimiter=";")

# read second csv file
df2 = pd.read_csv(file_path2, delimiter=";")

# read third csv file
df3 = pd.read_csv(file_path3, delimiter=";")

# Combine dataframe
combined_df = pd.concat([df1, df2, df3], ignore_index=True)

# Save combined data to csv file
combined_df.to_csv('combined_file.csv', index=False)

# %%
#Display head of combined data
combined_df.head()
# Out:
#                        created_at               id_str  \
# 0  Wed Feb 28 15:37:40 +0000 2024  1762864652923662643
# 1  Sun Feb 25 04:36:15 +0000 2024  1761611036908757295
# 2  Fri Feb 23 15:28:53 +0000 2024  1761050502849323295
# 3  Mon Feb 19 07:16:57 +0000 2024  1759477153195081994
# 4  Sun Feb 18 18:14:10 +0000 2024  1759280159209971827
#
#                                            full_text  quote_count  \
# 0                                               Gais            1
# 1  Buat ini perlu perjuangan Gais  Yang pertama g...            4
# 2      Gais sr nya besokkk yaw sambil otw theater😊🫶🏻            6
# 3                                               Gais            4
# 4  Gais besokkk ya jadi nya mauu srrr ,hehe maaf ...            2
#
#    reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0          146             54            4554   lt  1586992742093103104
# 1           66             77            4166   in  1586992742093103104
# ...

# %%
# Display information of combined data
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           104 non-null    object
#  1   id_str               104 non-null    int64
#  2   full_text            104 non-null    object
#  3   quote_count          104 non-null    int64
#  4   reply_count          104 non-null    int64
#  5   retweet_count        104 non-null    int64
#  6   favorite_count       104 non-null    int64
#  7   lang                 104 non-null    object
#  8   user_id_str          104 non-null    int64
#  9   conversation_id_str  104 non-null    int64
#  10  username             104 non-null    object
#  11  tweet_url            104 non-null    object
# dtypes: int64(7), object(5)
# memory usage: 9.9+ KB

# %%
# Check for duplicated values based on 'id_str' column
duplicated_values = combined_df[combined_df.duplicated(subset=['id_str'])]
print(duplicated_values)
# Out:
#                          created_at               id_str  \
# 83   Sat Jan 21 15:55:38 +0000 2023  1616826864265498631
# 84   Tue Dec 20 14:59:51 +0000 2022  1605216416428199936
# 86   Tue Dec 20 14:59:51 +0000 2022  1605216416428199936
# 87   Fri Nov 10 05:01:47 +0000 2023  1722841963312103897
# 89   Wed Jun 14 10:22:16 +0000 2023  1668926822803980288
# 90   Thu Mar 02 06:15:39 +0000 2023  1631176423569502208
# 91   Sat Feb 25 03:44:22 +0000 2023  1629326409100558336
# 92   Thu Feb 23 13:46:37 +0000 2023  1628753194598932482
# 95   Sat Jan 21 15:55:38 +0000 2023  1616826864265498631
# 101  Thu Dec 29 09:23:08 +0000 2022  1608393168621539332
# 102  Tue Dec 20 14:59:51 +0000 2022  1605216416428199936
#
#                                              full_text  quote_count  \
# 83   Ini part 2nya ya gais… Jadi aku sama ci @Graci...            4
# 84   @Y_CynthiaJKT48 IYA GAISS,kita itu udah niat b...            1
# 86   @Y_CynthiaJKT48 IYA GAISS,kita itu udah niat b...            1
# ...

# %%
# Drop duplicated values
combined_df = combined_df.drop_duplicates()
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 0 to 103
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           96 non-null     object
#  1   id_str               96 non-null     int64
#  2   full_text            96 non-null     object
#  3   quote_count          96 non-null     int64
#  4   reply_count          96 non-null     int64
#  5   retweet_count        96 non-null     int64
#  6   favorite_count       96 non-null     int64
#  7   lang                 96 non-null     object
#  8   user_id_str          96 non-null     int64
#  9   conversation_id_str  96 non-null     int64
#  10  username             96 non-null     object
#  11  tweet_url            96 non-null     object
# dtypes: int64(7), object(5)
# memory usage: 9.8+ KB

# %%
# Perform feature engineering: convert 'full_text' to lowercase
combined_df['full_text'] = combined_df['full_text'].apply(lambda x: x.lower())

# Select specific columns for further analysis
selected_columns = ['created_at', 'id_str', 'full_text','tweet_url']
df = combined_df[selected_columns]
df.head()
# Out:
# <ipython-input-31-bd3e64bcb607>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['full_text'] = combined_df['full_text'].apply(lambda x: x.lower())
#                        created_at               id_str  \
# 0  Wed Feb 28 15:37:40 +0000 2024  1762864652923662643
# 1  Sun Feb 25 04:36:15 +0000 2024  1761611036908757295
# 2  Fri Feb 23 15:28:53 +0000 2024  1761050502849323295
# 3  Mon Feb 19 07:16:57 +0000 2024  1759477153195081994
# 4  Sun Feb 18 18:14:10 +0000 2024  1759280159209971827
#
#                                            full_text  \
# 0                                               gais
# 1  buat ini perlu perjuangan gais  yang pertama g...
# 2      gais sr nya besokkk yaw sambil otw theater😊🫶🏻
# ...

# %%
# Display information of selected data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 0 to 103
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  96 non-null     object
#  1   id_str      96 non-null     int64
#  2   full_text   96 non-null     object
#  3   tweet_url   96 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 5.8+ KB

# %%
# Save selected data to Excel file
df.to_excel('FinalCathyGaisCounting.xlsx', index=False)

# %%
# Count occurrences of 'gais', 'gaiss', and 'gaisss' in 'full_text' column
df['Jumlah'] = df['full_text'].str.count(r'gais{1,3}\b')
total = df['Jumlah'].sum()

# Print total occurrences of the "Gais" words
print(f"Jumlah Kemunculan kata 'gais' di akun X N_CathyJKT48 sebanyak: {total},dari {jumlah_baris} post")
# Out:
# Jumlah Kemunculan kata 'gais' di akun X N_CathyJKT48 sebanyak: 102,dari 96 post
# <ipython-input-34-b053bc48f00e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Jumlah'] = df['full_text'].str.count(r'gais{1,3}\b')
